# %%
import pandas as pd
import numpy as np

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
df=pd.read_csv('/content/cbb.csv')

# %%
df
# Out:
#                 TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0     North Carolina   ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1          Wisconsin   B10  40  36  129.1   93.6   0.9758   54.8   47.7  12.4
# 2           Michigan   B10  40  33  114.4   90.4   0.9375   53.9   47.7  14.0
# 3         Texas Tech   B12  38  31  115.2   85.2   0.9696   53.5   43.0  17.7
# 4            Gonzaga   WCC  39  37  117.8   86.3   0.9728   56.6   41.1  16.2
# ...              ...   ...  ..  ..    ...    ...      ...    ...    ...   ...
# 3518          Toledo   MAC  34  27  119.9  109.6   0.7369   56.3   52.9  13.6
# 3519         Liberty  ASun  33  27  111.4   97.3   0.8246   55.5   49.3  16.0
# 3520     Utah Valley   WAC  34  28  107.1   94.6   0.8065   51.7   44.0  19.3
# 3521             UAB  CUSA  38  29  112.4   97.0   0.8453   50.3   47.3  17.3
# 3522     North Texas  CUSA  36  31  110.0   93.8   0.8622   51.2   44.5  19.8
#
# ...

# %%
df.dtypes
# Out:
# TEAM           object
# CONF           object
# G               int64
# W               int64
# ADJOE         float64
# ADJDE         float64
# BARTHAG       float64
# EFG_O         float64
# EFG_D         float64
# TOR           float64
# TORD          float64
# ORB           float64
# DRB           float64
# FTR           float64
# FTRD          float64
# 2P_O          float64
# 2P_D          float64
# 3P_O          float64
# 3P_D          float64
# ADJ_T         float64
# WAB           float64
# POSTSEASON     object
# SEED          float64
# YEAR            int64
# dtype: object

# %%
df.size
# Out:
# 84552

# %%
df.columns
# Out:
# Index(['TEAM', 'CONF', 'G', 'W', 'ADJOE', 'ADJDE', 'BARTHAG', 'EFG_O', 'EFG_D',
#        'TOR', 'TORD', 'ORB', 'DRB', 'FTR', 'FTRD', '2P_O', '2P_D', '3P_O',
#        '3P_D', 'ADJ_T', 'WAB', 'POSTSEASON', 'SEED', 'YEAR'],
#       dtype='object')

# %%
df.T
# Out:
#                       0          1         2           3        4     \
# TEAM        North Carolina  Wisconsin  Michigan  Texas Tech  Gonzaga
# CONF                   ACC        B10       B10         B12      WCC
# G                       40         40        40          38       39
# W                       33         36        33          31       37
# ADJOE                123.3      129.1     114.4       115.2    117.8
# ADJDE                 94.9       93.6      90.4        85.2     86.3
# BARTHAG             0.9531     0.9758    0.9375      0.9696   0.9728
# EFG_O                 52.6       54.8      53.9        53.5     56.6
# EFG_D                 48.1       47.7      47.7        43.0     41.1
# TOR                   15.4       12.4      14.0        17.7     16.2
# TORD                  18.2       15.8      19.5        22.8     17.1
# ORB                   40.7       32.1      25.5        27.4     30.0
# DRB                   30.0       23.7      24.9        28.7     26.2
# ...

# %%
df.head(3)
# Out:
#              TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0  North Carolina  ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1       Wisconsin  B10  40  36  129.1   93.6   0.9758   54.8   47.7  12.4
# 2        Michigan  B10  40  33  114.4   90.4   0.9375   53.9   47.7  14.0
#
#    ...  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR
# 0  ...  30.4  53.9  44.6  32.7  36.2   71.7   8.6         2ND   1.0  2016
# 1  ...  22.4  54.8  44.7  36.5  37.5   59.3  11.3         2ND   1.0  2015
# 2  ...  30.0  54.7  46.8  35.2  33.2   65.9   6.9         2ND   3.0  2018
#
# [3 rows x 24 columns]

# %%
df.tail(5)
# Out:
#              TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 3518       Toledo   MAC  34  27  119.9  109.6   0.7369   56.3   52.9  13.6
# 3519      Liberty  ASun  33  27  111.4   97.3   0.8246   55.5   49.3  16.0
# 3520  Utah Valley   WAC  34  28  107.1   94.6   0.8065   51.7   44.0  19.3
# 3521          UAB  CUSA  38  29  112.4   97.0   0.8453   50.3   47.3  17.3
# 3522  North Texas  CUSA  36  31  110.0   93.8   0.8622   51.2   44.5  19.8
#
#       ...  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T  WAB  POSTSEASON  SEED  YEAR
# 3518  ...  27.5  54.6  52.1  39.7  36.1   69.5 -1.2         NaN   NaN  2023
# 3519  ...  27.8  56.4  48.6  36.4  33.6   64.4 -2.0         NaN   NaN  2023
# 3520  ...  28.7  52.5  42.8  33.4  31.1   69.8 -0.3         NaN   NaN  2023
# 3521  ...  28.9  48.8  47.2  35.6  31.6   70.7 -0.5         NaN   NaN  2023
# 3522  ...  40.2  49.6  44.2  35.7  30.1   58.7  1.1         NaN   NaN  2023
#
# [5 rows x 24 columns]

# %%
df1=pd.read_csv('/content/cbb13.csv')

# %%
df1
# Out:
#                     TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D  \
# 0                Indiana   B10  36  29  121.0   89.7   0.9692   54.7   44.0
# 1                Gonzaga   WCC  34  31  118.9   90.2   0.9599   54.9   44.9
# 2                 Kansas   B12  37  31  111.6   86.2   0.9514   53.3   41.5
# 3             Louisville    BE  40  35  115.9   84.5   0.9743   50.6   44.8
# 4             Georgetown    BE  32  25  107.6   85.0   0.9381   51.1   43.0
# ..                   ...   ...  ..  ..    ...    ...      ...    ...    ...
# 342     Prairie View A&M  SWAC  31  12   87.1  103.5   0.1209   41.3   46.9
# 343              Buffalo   MAC  32  12  102.5  103.4   0.4761   50.4   47.2
# 344  Louisiana Lafayette    SB  32  12   98.4  105.3   0.3135   48.6   48.8
# 345      Bethune Cookman  MEAC  32  12   96.0  107.5   0.2134   45.9   51.0
# 346                 Troy    SB  33  12   97.3  107.5   0.2416   45.3   51.0
#
# ...

# %%
cols=['A','B','C','D','E']
df1 = pd.read_csv('/content/cbb13.csv', names=cols)
df1
# Out:
#                                                                                                                 A  \
# TEAM                CONF G  W  ADJOE ADJDE BARTHAG EFG_O EFG_D TOR  TORD ORB  DRB  FTR  FTRD 2P_O 2P_D 3P_O  3P_D
# Indiana             B10  36 29 121   89.7  0.9692  54.7  44    19.3 20.9 39   31.4 45.8 27   52   43.2 40.3  30.4
# Gonzaga             WCC  34 31 118.9 90.2  0.9599  54.9  44.9  17.2 20.8 37.8 29.8 40.8 29.9 55   42.1 36.5  32.9
# Kansas              B12  37 31 111.6 86.2  0.9514  53.3  41.5  20.3 18.4 33.8 29.3 39.5 32   52.9 39.3 36.4  30.3
# Louisville          BE   40 35 115.9 84.5  0.9743  50.6  44.8  18.3 27   38.2 33.3 40   34.9 50.8 43.4 33.3  31.8
# ...                                                                                                           ...
# Prairie View A&M    SWAC 31 12 87.1  103.5 0.1209  41.3  46.9  21.6 21.1 38.6 33.4 32.6 43.7 42   46.9 26    31.3
# ...

# %%
df3=pd.read_csv('/content/cbb14.csv')
df3
# Out:
#                TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0           Arizona   P12  38  33  116.2   87.4   0.9636   51.7   42.3  15.7
# 1           Florida   SEC  39  36  115.9   88.4   0.9575   52.2   45.4  17.5
# 2          Virginia   ACC  37  30  114.6   89.5   0.9449   50.8   44.2  16.5
# 3       Wichita St.   MVC  35  34  116.4   93.0   0.9295   52.4   44.7  16.2
# 4            Kansas   B12  35  25  119.2   95.6   0.9270   54.2   47.1  19.1
# ..              ...   ...  ..  ..    ...    ...      ...    ...    ...   ...
# 346        Winthrop  BSth  30  17  103.2  108.9   0.3487   50.9   52.5  18.6
# 347      Wright St.  Horz  34  19   99.5   97.3   0.5647   51.2   48.6  20.3
# 348         Wyoming   MWC  31  16  104.9   99.9   0.6368   52.7   46.2  16.9
# 349            Yale   Ivy  32  18  101.5  101.4   0.5030   46.2   50.2  19.7
# 350  Youngstown St.  Horz  29  12  107.0  108.4   0.4626   52.2   52.2  16.1
#
# ...

# %%
df2=pd.read_csv('/content/cbb14.csv', nrows=6)
df2
# Out:
#           TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  ...  \
# 0      Arizona  P12  38  33  116.2   87.4   0.9636   51.7   42.3  15.7  ...
# 1      Florida  SEC  39  36  115.9   88.4   0.9575   52.2   45.4  17.5  ...
# 2     Virginia  ACC  37  30  114.6   89.5   0.9449   50.8   44.2  16.5  ...
# 3  Wichita St.  MVC  35  34  116.4   93.0   0.9295   52.4   44.7  16.2  ...
# 4       Kansas  B12  35  25  119.2   95.6   0.9270   54.2   47.1  19.1  ...
# 5     Michigan  B10  37  28  125.0   99.9   0.9295   55.7   49.4  14.8  ...
#
#     FTR  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED
# 0  41.0  34.2  50.7  40.2  36.4  32.0   64.3   9.4          E8     1
# 1  42.4  31.2  51.3  43.5  35.9  33.0   63.1  11.7          F4     1
# 2  42.0  32.5  49.0  42.1  36.9  32.3   61.2   8.2         S16     1
# 3  46.9  35.7  52.3  43.6  35.0  31.1   65.1   8.1         R32     1
# 4  48.3  45.5  55.5  44.3  34.0  35.5   68.2   6.9         R32     2
# ...

# %%
x=df.iloc[2:8, 1:4]
x
# Out:
#   CONF   G   W
# 2  B10  40  33
# 3  B12  38  31
# 4  WCC  39  37
# 5  SEC  40  29
# 6  B10  38  30
# 7  ACC  39  35

# %%
df.iloc[2: , 1:]
# Out:
#       CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  TORD  ...  \
# 2      B10  40  33  114.4   90.4   0.9375   53.9   47.7  14.0  19.5  ...
# 3      B12  38  31  115.2   85.2   0.9696   53.5   43.0  17.7  22.8  ...
# 4      WCC  39  37  117.8   86.3   0.9728   56.6   41.1  16.2  17.1  ...
# 5      SEC  40  29  117.2   96.2   0.9062   49.9   46.0  18.1  16.1  ...
# 6      B10  38  30  121.5   93.7   0.9522   54.6   48.0  14.6  18.7  ...
# ...    ...  ..  ..    ...    ...      ...    ...    ...   ...   ...  ...
# 3518   MAC  34  27  119.9  109.6   0.7369   56.3   52.9  13.6  18.3  ...
# 3519  ASun  33  27  111.4   97.3   0.8246   55.5   49.3  16.0  18.9  ...
# 3520   WAC  34  28  107.1   94.6   0.8065   51.7   44.0  19.3  16.3  ...
# 3521  CUSA  38  29  112.4   97.0   0.8453   50.3   47.3  17.3  19.3  ...
# 3522  CUSA  36  31  110.0   93.8   0.8622   51.2   44.5  19.8  19.9  ...
#
#       FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T  WAB  POSTSEASON  SEED  YEAR
# ...

# %%
df.iloc[[4,7,8,9], 1:4]
# Out:
#   CONF   G   W
# 4  WCC  39  37
# 7  ACC  39  35
# 8  ACC  38  35
# 9  ACC  39  33

# %%
df.iloc[[4,7,2,8], [3,0,1]]
# Out:
#     W      TEAM CONF
# 4  37   Gonzaga  WCC
# 7  35      Duke  ACC
# 2  33  Michigan  B10
# 8  35  Virginia  ACC

# %%
df.iloc[4, :]
# Out:
# TEAM          Gonzaga
# CONF              WCC
# G                  39
# W                  37
# ADJOE           117.8
# ADJDE            86.3
# BARTHAG        0.9728
# EFG_O            56.6
# EFG_D            41.1
# TOR              16.2
# TORD             17.1
# ORB              30.0
# DRB              26.2
# FTR              39.0
# FTRD             26.9
# 2P_O             56.3
# 2P_D             40.0
# 3P_O             38.2
# 3P_D             29.0
# ADJ_T            71.5
# WAB               7.7
# POSTSEASON        2ND
# SEED              1.0
# YEAR             2017
# Name: 4, dtype: object

# %%
df.iloc[:,1]
# Out:
# 0        ACC
# 1        B10
# 2        B10
# 3        B12
# 4        WCC
#         ...
# 3518     MAC
# 3519    ASun
# 3520     WAC
# 3521    CUSA
# 3522    CUSA
# Name: CONF, Length: 3523, dtype: object

# %%
df.loc[: , 'TEAM']
# Out:
# 0       North Carolina
# 1            Wisconsin
# 2             Michigan
# 3           Texas Tech
# 4              Gonzaga
#              ...
# 3518            Toledo
# 3519           Liberty
# 3520       Utah Valley
# 3521               UAB
# 3522       North Texas
# Name: TEAM, Length: 3523, dtype: object

# %%
df['CONF']
# Out:
# 0        ACC
# 1        B10
# 2        B10
# 3        B12
# 4        WCC
#         ...
# 3518     MAC
# 3519    ASun
# 3520     WAC
# 3521    CUSA
# 3522    CUSA
# Name: CONF, Length: 3523, dtype: object

# %%
df.TEAM
# Out:
# 0       North Carolina
# 1            Wisconsin
# 2             Michigan
# 3           Texas Tech
# 4              Gonzaga
#              ...
# 3518            Toledo
# 3519           Liberty
# 3520       Utah Valley
# 3521               UAB
# 3522       North Texas
# Name: TEAM, Length: 3523, dtype: object

# %%
df.drop([5,8])
# Out:
#                 TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0     North Carolina   ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1          Wisconsin   B10  40  36  129.1   93.6   0.9758   54.8   47.7  12.4
# 2           Michigan   B10  40  33  114.4   90.4   0.9375   53.9   47.7  14.0
# 3         Texas Tech   B12  38  31  115.2   85.2   0.9696   53.5   43.0  17.7
# 4            Gonzaga   WCC  39  37  117.8   86.3   0.9728   56.6   41.1  16.2
# ...              ...   ...  ..  ..    ...    ...      ...    ...    ...   ...
# 3518          Toledo   MAC  34  27  119.9  109.6   0.7369   56.3   52.9  13.6
# 3519         Liberty  ASun  33  27  111.4   97.3   0.8246   55.5   49.3  16.0
# 3520     Utah Valley   WAC  34  28  107.1   94.6   0.8065   51.7   44.0  19.3
# 3521             UAB  CUSA  38  29  112.4   97.0   0.8453   50.3   47.3  17.3
# 3522     North Texas  CUSA  36  31  110.0   93.8   0.8622   51.2   44.5  19.8
#
# ...

# %%
df.drop('G', axis=1)
# Out:
#                 TEAM  CONF   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0     North Carolina   ACC  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1          Wisconsin   B10  36  129.1   93.6   0.9758   54.8   47.7  12.4
# 2           Michigan   B10  33  114.4   90.4   0.9375   53.9   47.7  14.0
# 3         Texas Tech   B12  31  115.2   85.2   0.9696   53.5   43.0  17.7
# 4            Gonzaga   WCC  37  117.8   86.3   0.9728   56.6   41.1  16.2
# ...              ...   ...  ..    ...    ...      ...    ...    ...   ...
# 3518          Toledo   MAC  27  119.9  109.6   0.7369   56.3   52.9  13.6
# 3519         Liberty  ASun  27  111.4   97.3   0.8246   55.5   49.3  16.0
# 3520     Utah Valley   WAC  28  107.1   94.6   0.8065   51.7   44.0  19.3
# 3521             UAB  CUSA  29  112.4   97.0   0.8453   50.3   47.3  17.3
# 3522     North Texas  CUSA  31  110.0   93.8   0.8622   51.2   44.5  19.8
#
#       TORD  ...  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  \
# ...

# %%
help(df.drop)
# Out:
# Help on method drop in module pandas.core.frame:
#
# drop(labels: 'IndexLabel' = None, *, axis: 'Axis' = 0, index: 'IndexLabel' = None, columns: 'IndexLabel' = None, level: 'Level' = None, inplace: 'bool' = False, errors: 'IgnoreRaise' = 'raise') -> 'DataFrame | None' method of pandas.core.frame.DataFrame instance
#     Drop specified labels from rows or columns.
#
#     Remove rows or columns by specifying label names and corresponding
#     axis, or by specifying directly index or column names. When using a
#     multi-index, labels on different levels can be removed by specifying
#     the level. See the :ref:`user guide <advanced.shown_levels>`
#     for more information about the now unused levels.
#
#     Parameters
#     ----------
#     labels : single label or list-like
#         Index or column labels to drop. A tuple will be used as a single
#         label and not treated as a list-like.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
# ...

# %%
df['EFG_O'].mean()
# Out:
# 49.88782287822878

# %%
df['EFG_O'].max()
# Out:
# 61.0

# %%
df['EFG_O'].min()
# Out:
# 39.2

# %%
df['EFG_O'].sum()
# Out:
# 175754.8

# %%
df['EFG_O'].median()
# Out:
# 49.8

# %%
df.mean(numeric_only=True)
# Out:
# G            30.486233
# W            15.990633
# ADJOE       103.151320
# ADJDE       103.153250
# BARTHAG       0.494067
# EFG_O        49.887823
# EFG_D        50.087113
# TOR          18.696509
# TORD         18.625092
# ORB          29.308544
# DRB          29.516747
# FTR          34.529066
# FTRD         34.802555
# 2P_O         49.112433
# 2P_D         49.289299
# 3P_O         34.185580
# 3P_D         34.369316
# ADJ_T        67.735339
# WAB          -7.579620
# SEED          8.801471
# YEAR       2017.828555
# dtype: float64

# %%
df.count()
# Out:
# roll     10
# name     10
# class    10
# marks    10
# age      10
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3523 entries, 0 to 3522
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TEAM        3523 non-null   object
#  1   CONF        3523 non-null   object
#  2   G           3523 non-null   int64
#  3   W           3523 non-null   int64
#  4   ADJOE       3523 non-null   float64
#  5   ADJDE       3523 non-null   float64
#  6   BARTHAG     3523 non-null   float64
#  7   EFG_O       3523 non-null   float64
#  8   EFG_D       3523 non-null   float64
#  9   TOR         3523 non-null   float64
#  10  TORD        3523 non-null   float64
#  11  ORB         3523 non-null   float64
#  12  DRB         3523 non-null   float64
#  13  FTR         3523 non-null   float64
#  14  FTRD        3523 non-null   float64
#  15  2P_O        3523 non-null   float64
#  16  2P_D        3523 non-null   float64
#  17  3P_O        3523 non-null   float64
# ...

# %%
df.describe()
# Out:
#                  G            W        ADJOE        ADJDE      BARTHAG  \
# count  3523.000000  3523.000000  3523.000000  3523.000000  3523.000000
# mean     30.486233    15.990633   103.151320   103.153250     0.494067
# std       3.951584     6.572893     7.264859     6.511989     0.255338
# min       5.000000     0.000000    76.600000    84.000000     0.005000
# 25%      29.000000    11.000000    98.200000    98.400000     0.281300
# 50%      31.000000    16.000000   102.800000   103.200000     0.475600
# 75%      33.000000    21.000000   107.900000   107.800000     0.714250
# max      40.000000    38.000000   129.100000   124.000000     0.984200
#
#              EFG_O        EFG_D          TOR         TORD          ORB  ...  \
# count  3523.000000  3523.000000  3523.000000  3523.000000  3523.000000  ...
# mean     49.887823    50.087113    18.696509    18.625092    29.308544  ...
# std       3.078505     2.894967     2.104119     2.241067     4.214131  ...
# ...

# %%
df['EFG_O']=df['EFG_O'] + 0.52

# %%
df
# Out:
#                 TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0     North Carolina   ACC  40  33  123.3   94.9   0.9531  53.12   48.1  15.4
# 1          Wisconsin   B10  40  36  129.1   93.6   0.9758  55.32   47.7  12.4
# 2           Michigan   B10  40  33  114.4   90.4   0.9375  54.42   47.7  14.0
# 3         Texas Tech   B12  38  31  115.2   85.2   0.9696  54.02   43.0  17.7
# 4            Gonzaga   WCC  39  37  117.8   86.3   0.9728  57.12   41.1  16.2
# ...              ...   ...  ..  ..    ...    ...      ...    ...    ...   ...
# 3518          Toledo   MAC  34  27  119.9  109.6   0.7369  56.82   52.9  13.6
# 3519         Liberty  ASun  33  27  111.4   97.3   0.8246  56.02   49.3  16.0
# 3520     Utah Valley   WAC  34  28  107.1   94.6   0.8065  52.22   44.0  19.3
# 3521             UAB  CUSA  38  29  112.4   97.0   0.8453  50.82   47.3  17.3
# 3522     North Texas  CUSA  36  31  110.0   93.8   0.8622  51.72   44.5  19.8
#
# ...

# %%
df['EFG_O']=df['EFG_O'] /10 + 0.27

# %%
df
# Out:
#                 TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG   EFG_O  EFG_D  \
# 0     North Carolina   ACC  40  33  123.3   94.9   0.9531  0.8282   48.1
# 1          Wisconsin   B10  40  36  129.1   93.6   0.9758  0.8502   47.7
# 2           Michigan   B10  40  33  114.4   90.4   0.9375  0.8412   47.7
# 3         Texas Tech   B12  38  31  115.2   85.2   0.9696  0.8372   43.0
# 4            Gonzaga   WCC  39  37  117.8   86.3   0.9728  0.8682   41.1
# ...              ...   ...  ..  ..    ...    ...      ...     ...    ...
# 3518          Toledo   MAC  34  27  119.9  109.6   0.7369  0.8652   52.9
# 3519         Liberty  ASun  33  27  111.4   97.3   0.8246  0.8572   49.3
# 3520     Utah Valley   WAC  34  28  107.1   94.6   0.8065  0.8192   44.0
# 3521             UAB  CUSA  38  29  112.4   97.0   0.8453  0.8052   47.3
# 3522     North Texas  CUSA  36  31  110.0   93.8   0.8622  0.8142   44.5
#
#        TOR  ...  FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  \
# ...

# %%
df['TEAM']=df['EFG_O']=df['EFG_O']/ + 0.27

# %%
df
# Out:
#           TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG     EFG_O  EFG_D   TOR  \
# 0     3.067407   ACC  40  33  123.3   94.9   0.9531  3.067407   48.1  15.4
# 1     3.148889   B10  40  36  129.1   93.6   0.9758  3.148889   47.7  12.4
# 2     3.115556   B10  40  33  114.4   90.4   0.9375  3.115556   47.7  14.0
# 3     3.100741   B12  38  31  115.2   85.2   0.9696  3.100741   43.0  17.7
# 4     3.215556   WCC  39  37  117.8   86.3   0.9728  3.215556   41.1  16.2
# ...        ...   ...  ..  ..    ...    ...      ...       ...    ...   ...
# 3518  3.204444   MAC  34  27  119.9  109.6   0.7369  3.204444   52.9  13.6
# 3519  3.174815  ASun  33  27  111.4   97.3   0.8246  3.174815   49.3  16.0
# 3520  3.034074   WAC  34  28  107.1   94.6   0.8065  3.034074   44.0  19.3
# 3521  2.982222  CUSA  38  29  112.4   97.0   0.8453  2.982222   47.3  17.3
# 3522  3.015556  CUSA  36  31  110.0   93.8   0.8622  3.015556   44.5  19.8
#
# ...

# %%
df=pd.read_csv('/content/cbb.csv')

# %%
df
# Out:
#                 TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  \
# 0     North Carolina   ACC  40  33  123.3   94.9   0.9531   52.6   48.1  15.4
# 1          Wisconsin   B10  40  36  129.1   93.6   0.9758   54.8   47.7  12.4
# 2           Michigan   B10  40  33  114.4   90.4   0.9375   53.9   47.7  14.0
# 3         Texas Tech   B12  38  31  115.2   85.2   0.9696   53.5   43.0  17.7
# 4            Gonzaga   WCC  39  37  117.8   86.3   0.9728   56.6   41.1  16.2
# ...              ...   ...  ..  ..    ...    ...      ...    ...    ...   ...
# 3518          Toledo   MAC  34  27  119.9  109.6   0.7369   56.3   52.9  13.6
# 3519         Liberty  ASun  33  27  111.4   97.3   0.8246   55.5   49.3  16.0
# 3520     Utah Valley   WAC  34  28  107.1   94.6   0.8065   51.7   44.0  19.3
# 3521             UAB  CUSA  38  29  112.4   97.0   0.8453   50.3   47.3  17.3
# 3522     North Texas  CUSA  36  31  110.0   93.8   0.8622   51.2   44.5  19.8
#
# ...

# %%
pd.concat([df,df1])
# Out:
#                                                               TEAM CONF     G  \
# 0                                                   North Carolina  ACC  40.0
# 1                                                        Wisconsin  B10  40.0
# 2                                                         Michigan  B10  40.0
# 3                                                       Texas Tech  B12  38.0
# 4                                                          Gonzaga  WCC  39.0
# ...                                                            ...  ...   ...
# (Prairie View A&M, SWAC, 31, 12, 87.1, 103.5, 0...             NaN  NaN   NaN
# (Buffalo, MAC, 32, 12, 102.5, 103.4, 0.4761, 50...             NaN  NaN   NaN
# (Louisiana Lafayette, SB, 32, 12, 98.4, 105.3, ...             NaN  NaN   NaN
# (Bethune Cookman, MEAC, 32, 12, 96, 107.5, 0.21...             NaN  NaN   NaN
# (Troy, SB, 33, 12, 97.3, 107.5, 0.2416, 45.3, 5...             NaN  NaN   NaN
#
# ...

# %%
df['TEAM'].str.upper()
# Out:
# 0       NORTH CAROLINA
# 1            WISCONSIN
# 2             MICHIGAN
# 3           TEXAS TECH
# 4              GONZAGA
#              ...
# 3518            TOLEDO
# 3519           LIBERTY
# 3520       UTAH VALLEY
# 3521               UAB
# 3522       NORTH TEXAS
# Name: TEAM, Length: 3523, dtype: object

# %%
df['TEAM'].str.startswith('I')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3518    False
# 3519    False
# 3520    False
# 3521    False
# 3522    False
# Name: TEAM, Length: 3523, dtype: bool

# %%
df['TEAM'].str.endswith('l')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3518    False
# 3519    False
# 3520    False
# 3521    False
# 3522    False
# Name: TEAM, Length: 3523, dtype: bool

# %%
df['TEAM'].str.replace('i', 'ee')
# Out:
# 0       North Caroleena
# 1           Weesconseen
# 2            Meecheegan
# 3            Texas Tech
# 4               Gonzaga
#              ...
# 3518             Toledo
# 3519           Leeberty
# 3520        Utah Valley
# 3521                UAB
# 3522        North Texas
# Name: TEAM, Length: 3523, dtype: object

# %%
df['TEAM'].str.replace('i', 'uu')
# Out:
# 0       North Caroluuna
# 1           Wuusconsuun
# 2            Muuchuugan
# 3            Texas Tech
# 4               Gonzaga
#              ...
# 3518             Toledo
# 3519           Luuberty
# 3520        Utah Valley
# 3521                UAB
# 3522        North Texas
# Name: TEAM, Length: 3523, dtype: object

# %%
df[df['EFG_O'] >60]
# Out:
#          TEAM CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  ...  \
# 2458  Gonzaga  WCC  26  26  125.4   89.8   0.9791   61.0   47.5  16.1  ...
#
#       FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T  WAB  POSTSEASON  SEED  YEAR
# 2458  25.9  64.0  46.8  36.5  32.5   74.6  8.5         2ND   1.0  2021
#
# [1 rows x 24 columns]

# %%
x=df['TEAM'].str.replace('i', 'ef')
x
# Out:
# 0       North Carolefna
# 1           Wefsconsefn
# 2            Mefchefgan
# 3            Texas Tech
# 4               Gonzaga
#              ...
# 3518             Toledo
# 3519           Lefberty
# 3520        Utah Valley
# 3521                UAB
# 3522        North Texas
# Name: TEAM, Length: 3523, dtype: object
